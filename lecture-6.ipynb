# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as sts

# %matplotlib inline

# %% [markdown]
# ### Нормальное распределение

# %%
mu = 2.0
sigma = 0.5

# зададим нормально распределенную случайную величину
norm_rv = sts.norm(loc=mu, scale=sigma)

# сгенерируем 10 значений
norm_rv.rvs(size=10)
# Out:
# array([1.32075542, 1.87925099, 3.19329038, 1.50120935, 2.01523973,
#        1.66441037, 1.40808052, 2.17976504, 1.91338985, 2.78322131])

# %% [markdown]
# Параметр ```loc``` задаёт $\mu$, ```scale``` — среднеквадратичное отклонение $\sigma$, ```size``` — размер выборки. Имя параметра ```size``` при вызове функции ```rvs``` можно не писать.

# %%
norm_rv.cdf(3)
# Out:
# 0.9772498680518208

# %%
x = np.linspace(0,4,100)
cdf = norm_rv.cdf(x) # функция может принимать и вектор (x)
plt.plot(x, cdf)
plt.ylabel('$F(x)$')
plt.xlabel('$x$')
plt.show()

# %%
norm_rv.pdf(3)
# Out:
# 0.10798193302637613

# %%
x = np.linspace(0,4,100)
pdf = norm_rv.pdf(x)
plt.plot(x, pdf)

plt.ylabel('$f(x)$')
plt.xlabel('$x$')
plt.show()

# %% [markdown]
# ### Равномерное распределение на отрезке

# %%
a = 1
b = 4

# обратите внимание, что в этой функции задается левая граница и масштаб, а не левая и правая границы:
uniform_rv = sts.uniform(a, b-a)

uniform_rv.rvs(10)
# Out:
# array([1.2853015 , 1.76217901, 1.4837676 , 3.11608716, 2.48071534,
#        2.19564752, 2.26084079, 3.37152618, 3.41740713, 1.85511775])

# %%
x = np.linspace(0,5,100)
cdf = uniform_rv.cdf(x)
plt.plot(x, cdf)

plt.ylabel('$F(x)$')
plt.xlabel('$x$')
plt.show()

# %%
x = np.linspace(0,5,1000)
pdf = uniform_rv.pdf(x)
plt.plot(x, pdf)

plt.ylabel('$f(x)$')
plt.xlabel('$x$')
plt.show()

# %% [markdown]
# ### Экспоненциальное распредление

# %%
lam = 0.1

expon_rv = sts.expon(lam)

expon_rv.rvs(10)
# Out:
# array([0.17460432, 0.71076815, 0.20756784, 2.00334463, 0.13374002,
#        0.88763609, 2.33902922, 0.25857695, 0.35758519, 0.53382361])

# %%
x = np.linspace(0,5,100)
cdf = expron_rv.cdf(x)
plt.plot(x, cdf)

plt.ylabel('$F(x)$')
plt.xlabel('$x$')
plt.show()

# %%
x = np.linspace(0,5,1000)
pdf = expon_rv.pdf(x)
plt.plot(x, pdf)

plt.ylabel('$f(x)$')
plt.xlabel('$x$')
plt.show()

# %% [markdown]
# ### Распределение Стьюдента

# %%
n = 10

t_rv = sts.t(n)

t_rv.rvs(10)
# Out:
# array([-1.79256774, -0.4293779 , -1.12665525, -1.22751042, -1.16395528,
#         0.42538999, -0.97521322,  1.30606174, -0.41304665, -0.17785034])

# %%
x = np.linspace(-5,5,100)
cdf = t_rv.cdf(x)
plt.plot(x, cdf)

plt.ylabel('$F(x)$')
plt.xlabel('$x$')
plt.show()

# %%
x = np.linspace(-5,5,1000)
pdf = t_rv.pdf(x)
plt.plot(x, pdf)

plt.ylabel('$f(x)$')
plt.xlabel('$x$')
plt.show()
