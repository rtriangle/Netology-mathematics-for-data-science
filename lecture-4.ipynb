# %%
import matplotlib.pyplot as plt
import numpy as np
import pylab

from scipy.misc import derivative
from scipy.misc import electrocardiogram
from scipy.optimize import fmin
from scipy.signal import find_peaks

# %% [markdown]
# ### Скорость

# %%
arr = np.random.rand(1000000)
arr.shape
# Out:
# (1000000,)

# %%
# %timeit sum(arr)
# %timeit np.sum(arr)

# %timeit min(arr)
# %timeit np.min(arr)

# %timeit max(arr)
# %timeit np.max(arr)
# Out:
# 192 ms ± 10.3 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 612 µs ± 81.6 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 174 ms ± 39.1 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 1.03 ms ± 479 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 125 ms ± 11.4 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 679 µs ± 40.8 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %% [markdown]
# ### Поиск экстремумов

# %%
def f(x):
    return -1 * np.sin(x)/x

# %%
def f_(x):
    return -f(x)

# %% [markdown]
# ### Поиск локальных минимумов

# %%
# objective function

x0 = -5 # start from x = -5
xmin0 = fmin(f,x0)

x1 = -4 # start from x = -4
xmin1 = fmin(f,x1)

# plot the function
x = np.linspace(-15,15,100)
y = f(x)
pylab.plot(x,y)
# plot of x0 and the minimum found startin from x0
pylab.plot(x0, f(x0), 'bd', xmin0, f(xmin0), 'bo')
# plot of x1 and the minimum found startin from x1
pylab.plot(x1, f(x1), 'rd', xmin1, f(xmin1), 'ro')

pylab.axis([-15,15,-1.3,0.3])
pylab.show()
# Out:
# Optimization terminated successfully.
#          Current function value: -0.128375
#          Iterations: 18
#          Function evaluations: 36
# Optimization terminated successfully.
#          Current function value: -1.000000
#          Iterations: 19
#          Function evaluations: 38

# %% [markdown]
# ### Поиск локальных максимумов

# %%
# objective function

x0 = -5 # start from x = -5
xmin0 = fmin(f_,x0)

x1 = -4 # start from x = -4
xmin1 = fmin(f_, x1)

# plot the function
x = np.linspace(-15,15,100)
y = f(x)
pylab.plot(x,y)
# plot of x0 and the minimum found startin from x0
pylab.plot(x0, f(x0), 'bd', xmin0, f(xmin0), 'bo')
# plot of x1 and the minimum found startin from x1
pylab.plot(x1, f(x1), 'rd', xmin1, f(xmin1), 'ro')

pylab.axis([-15,15,-1.3,0.3])
pylab.show()
# Out:
# Optimization terminated successfully.
#          Current function value: -0.217234
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: -0.217234
#          Iterations: 13
#          Function evaluations: 26

# %%
x = electrocardiogram()[3000:3500]
peaks, _ = find_peaks(x, height=0)
plt.plot(x)
plt.plot(peaks, x[peaks], "x")
plt.plot(np.zeros_like(x), "--", color="gray")
plt.show()

# %%
x = electrocardiogram()[1000:4000]
peaks, _ = find_peaks(x, height=0)
plt.plot(x)
plt.plot(peaks, x[peaks], "x")
plt.plot(np.zeros_like(x), "--", color="gray")
plt.show()

# %%
x = np.array([np.sin(xx) for xx in np.linspace(0, 10, 100)])
peaks, _ = find_peaks(x, height=0)
plt.plot(x)
plt.plot(peaks, x[peaks], "x")
plt.plot(np.zeros_like(x), "--", color="gray")
plt.show()

# %%
x = np.array([np.sin(xx) for xx in np.linspace(0, 10, 100)])
peaks, _ = find_peaks(x)
plt.plot(x)
plt.plot(peaks, x[peaks], "x")
plt.plot(np.zeros_like(x), "--", color="gray")
plt.show()

# %% [markdown]
# ### Производная

# %%
from scipy.misc import derivative
def f(x):
    return x**3 + x**2
derivative(f, 1.0, dx=1e-6)
# Out:
# 4.999999999921734

# %%
def f(x):
    return x ** 2 + 1

# %%
x = np.linspace(-10, 10)
fx = f(x)
f1x = [derivative(f, xx, dx=1e-6) for xx in x]

# %%
plt.plot(x, fx, label='function')
plt.plot(x, f1x, label='derivative')
plt.legend()
plt.show()
